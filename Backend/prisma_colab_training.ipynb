# %% [markdown]
# # 🚀 PRISMA Model Training - Google Colab
# This notebook automates the training of the PRISMA ML models (XGBoost, CatBoost, LightGBM) using your Neon database.

# %% [markdown]
# ## 1. Setup & Dependencies
# Install the required machine learning libraries.

# %%
# !pip install xgboost catboost lightgbm psycopg2-binary python-dotenv pandas numpy scikit-learn requests rich

# %% [markdown]
# ## 2. Upload Backend Code
# Upload the `backend.zip` file containing your source code.

# %%
from google.colab import files
import os

if not os.path.exists('backend.zip'):
    print("Please upload backend.zip...")
    uploaded = files.upload()

# !unzip -q backend.zip
print("✅ Backend code extracted!")

# %% [markdown]
# ## 3. Configure Environment
# Set your Neon Database URL.

# %%
import os

# Your Neon Database URL provided in the request
DATABASE_URL = "postgresql://neondb_owner:npg_XFIOS9Yrn3TQ@ep-raspy-credit-amt5t8yu-pooler.c-5.us-east-1.aws.neon.tech/neondb?sslmode=require&channel_binding=require"

with open('.env', 'w') as f:
    f.write(f"DATABASE_URL={DATABASE_URL}\n")
    f.write("ENVIRONMENT=production\n")

print("✅ Environment configured with Neon DB!")

# %% [markdown]
# ## 4. Launch Training
# Start the training process with real-time monitoring (verbose mode).

# %%
# Change directory if needed (depending on zip structure)
# os.chdir('Backend') 

# !python scripts/local_training.py --force --verbose

# %% [markdown]
# ## 5. Download Models
# Zip the trained models for downloading or manual upload to Hugging Face.

# %%
# !zip -r prisma_models_trained.zip models/prisma/
from google.colab import files
files.download('prisma_models_trained.zip')
print("✅ Download started!")

# %% [markdown]
# ## 6. (Optional) Auto-upload to Hugging Face
# If you want to automate the upload right now, set your HF Token and Space ID.

# %%
HF_TOKEN = "your_token_here"
HF_SPACE_ID = "your_user/your_space"

if HF_TOKEN != "your_token_here":
    os.environ['HF_TOKEN'] = HF_TOKEN
    with open('.env', 'a') as f:
        f.write(f"HF_SPACE_ID={HF_SPACE_ID}\n")
    
    # !python scripts/upload_models_hf.py
else:
    print("Hugging Face upload skipped. Add your token to automate.")
